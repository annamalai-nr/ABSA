# %%
import os,sys,json,string,nltk
from gensim.models import word2vec
import numpy as np
import networkx as nx
from time import time
from pprint import pprint
from GetSentenceVectors import GetSentenceTensor, GetScaledSentenceTensor
import math
from copy import deepcopy

def LoadGoogleNewsW2VModel (ModelFName):
    T0 = time()
    print 'loading {} w2v model ...'.format(ModelFName)
    W2VModel = word2vec.Word2Vec.load_word2vec_format(ModelFName, binary=True)
    print 'loaded w2v model in {} sec.'.format(round(time()-T0,2))
    return W2VModel

def TokenizeWOStem(Sent):
    Sent = Sent.lower()
    SentChars = "".join([ch for ch in Sent if ch not in string.punctuation])
    Tokens = nltk.word_tokenize(SentChars)
    return Tokens

def GetMaxSentLen (TokenizedSentences):
    return max([len(T) for T in TokenizedSentences])

def GetSentenceToNxGraphDict (Sentences, CoreNLPParsedSents):
    SentenceToNxGraphDict = {}
    for S in Sentences:
        if S in SentenceToNxGraphDict.keys(): continue
        SentProcessed = False
        for SentCoreNLPInfoList in CoreNLPParsedSents:
            if SentProcessed: break
            if not SentCoreNLPInfoList: continue
            for SentCoreNLPDict in SentCoreNLPInfoList['sentences']:
                CoreNLPSent = SentCoreNLPDict['text']
                if CoreNLPSent == S:
                    G = nx.Graph();G.add_edges_from(SentCoreNLPDict['NxGraphEdges'])
                    SentenceToNxGraphDict[S] = deepcopy(G)
                    SentProcessed = True
                    break
    return SentenceToNxGraphDict

def GetHtAndUniqWordLabeledTokedSent (TokedSent):
    ReLabeledTokedSent = []
    for Index, W in enumerate(TokedSent):
        PrevWords = TokedSent[:Index]
        CountOfWSoFar = PrevWords.count(W)
        ReLabeledTokedSent.append('1_'+W+'_'+str(CountOfWSoFar+1))
    return ReLabeledTokedSent

def GetDistIJAndProbIJ (TokedSent, WOrg, TreeHt, G):
    DistIJs = {}
    ProbIJs = {}
    for IndexI, WordI in enumerate(TokedSent):
        for WordJ in TokedSent:
            if WordI == WordJ:
                DistIJs[(WordI, WordJ)] = 0
                ProbIJs[(WordI, WordJ)] = 1 + WOrg[IndexI]
            else:
                try:
                    ShortesPath = nx.shortest_path(G, WordI, WordJ)
                    DistIJs[(WordI, WordJ)] = len(ShortesPath) - 2
                except:
                    # print 'one of the words {} or {} is NOT present in parse tree' \
                    #       ', hence using maximum height of the tree as distance'.format(WordI, WordJ)
                    DistIJs[(WordI, WordJ)] = TreeHt  # make maximum height
                Frac = float(DistIJs[(WordI, WordJ)] * DistIJs[(WordI, WordJ)]) / (2 * TreeHt)
                ProbIJs[(WordI, WordJ)] = WOrg[IndexI] * math.exp(-Frac)
    return DistIJs, ProbIJs

def GetHtAndUniqWordLabeledAspTerm (ATerms, TokedSent):
    ATermsWithHtAnduniqCount = []
    for AT in ATerms:
        for W in TokedSent:
            if AT in W:
                ATermsWithHtAnduniqCount.append(W)
    return ATermsWithHtAnduniqCount

def GetWeightsAccToAspTerms (TokedSent, ATerms, ParseTreeNxGraph):
    ATerms = TokenizeWOStem(ATerms)
    G = ParseTreeNxGraph
    TreeHt = int(G.neighbors('ROOT')[0].split('_')[0])
    TokedSent = GetHtAndUniqWordLabeledTokedSent (TokedSent)
    ATerms = GetHtAndUniqWordLabeledAspTerm (ATerms, TokedSent)
    UniformPVal = 1.0/len(ATerms)
    WOrg = [UniformPVal if W in ATerms else 0 for W in TokedSent]
    DistIJs, ProbIJs = GetDistIJAndProbIJ(TokedSent, WOrg, TreeHt, G)
    WMod = [sum([ProbIJs[(WordI, WordJ)] for WordI, WordJ in ProbIJs.keys() if W == WordJ]) for W in TokedSent]
    del DistIJs, ProbIJs
    # pprint (WOrg)
    # pprint ([round(elem, 2) for elem in WMod])
    WModMean = float(np.array (WMod).mean())
    WMod = [X/WModMean for X in WMod]
    # pprint ([round(elem, 2) for elem in WMod])
    MinVal = min (WMod); MaxVal = max (WMod); ToMin = 0.7; ToMax = 1.3;ToDiff = ToMax - ToMin
    WModNormalized = [(((ToDiff)*(X-MinVal))/(MaxVal-MinVal))+ToMin for X in WMod]
    # pprint ([round(elem, 2) for elem in WModNormalized])
    return WModNormalized
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
NSamples = 200

#1 load sentences, aspect terms and sentiment labels
SentsAspectsLabelsFName = '../../../2014/Data/RestAspTermABSA.csv'
Sentences = [''.join(l.strip().split(';')[:-2]).lower() for l in open(SentsAspectsLabelsFName).xreadlines()][:NSamples]
AspectTerms = [''.join(l.strip().split(';')[-2]) for l in open(SentsAspectsLabelsFName).xreadlines()][:NSamples]
Labels = [''.join(l.strip().split(';')[-1]) for l in open(SentsAspectsLabelsFName).xreadlines()][:NSamples]
print 'loaded {} sentences, {} aspects and {} labels'.format(len(Sentences), len(AspectTerms), len(Labels))

CoreNLPParsedFName = '../../Data/CoreNLPParsed.ParseTreeConvertedAsNxGraph.json'
with open(CoreNLPParsedFName) as FH:
    CoreNLPParsedSents = json.load(FH)
print 'loaded {} sentences that are pased by core nlp'.format(len(CoreNLPParsedSents))

SentenceToNxGraphDict = GetSentenceToNxGraphDict (Sentences, CoreNLPParsedSents)
del CoreNLPParsedSents
print 'out of total {} sentences, loaded nx graph edges for {} sentences'.format(len(set(Sentences)),
                                                                                 len(SentenceToNxGraphDict))
#2 tokenize each sentence
TokenizedSentences = [TokenizeWOStem(S) for S in Sentences]
print 'tokenized sentences'
SentMaxLen = GetMaxSentLen (TokenizedSentences)
print 'max sentence lenght found across all sentences (size of sentence tensor): ', SentMaxLen
# Out:
# loaded 200 sentences, 200 aspects and 200 labels
# loaded 3714 sentences that are pased by core nlp
# out of total 101 sentences, loaded nx graph edges for 100 sentences
# tokenized sentences
# max sentence lenght found across all sentences (size of sentence tensor):  61

# %%
# 3 w2v model load
GoogleNewsW2VModelFName = '../../../Embeddings/GoolgeNews/GoogleNews-vectors-negative300.bin'
W2VModel = LoadGoogleNewsW2VModel(GoogleNewsW2VModelFName)
W2VDims = 300
# Out:
# loading ../../../Embeddings/GoolgeNews/GoogleNews-vectors-negative300.bin w2v model ...
# loaded w2v model in 49.23 sec.

# %%
UnScaledX = []
ScaledX = []
Y = []
for SentIndex, TokedSent in enumerate(TokenizedSentences):
    T0 = time()
    ATerms = AspectTerms[SentIndex]
    Sent = Sentences[SentIndex]
    try:
        ParseTreeNxGraph = SentenceToNxGraphDict[Sent]
        ATermWts = GetWeightsAccToAspTerms (TokedSent, ATerms, ParseTreeNxGraph)
    except:
        ATermWts = [1.0 for W in TokedSent]

    UnScaledSentenceTensor = GetSentenceTensor (TokedSent, SentMaxLen, W2VDims, W2VModel, Avg= False)
    ScaledSentenceTensor = GetScaledSentenceTensor (UnScaledSentenceTensor, ATermWts)

    #for save
    OrgDims = UnScaledSentenceTensor.shape[0]*UnScaledSentenceTensor.shape[1]
    UnScaledSentenceTensor = UnScaledSentenceTensor.reshape(1,OrgDims)
    ScaledSentenceTensor = ScaledSentenceTensor.reshape(1,OrgDims)
    UnScaledX.append(UnScaledSentenceTensor)
    ScaledX.append(ScaledSentenceTensor)
    Y.append(Labels[SentIndex])

    print 'proced sent: {} in {} sec.'.format(SentIndex, time()-T0)
# Out:
# proced sent: 0 in 0.00146389007568 sec.
# proced sent: 1 in 0.00125694274902 sec.
# proced sent: 2 in 0.000787019729614 sec.
# proced sent: 3 in 0.000534057617188 sec.
# proced sent: 4 in 0.000927209854126 sec.
# proced sent: 5 in 0.00725603103638 sec.
# proced sent: 6 in 0.00727605819702 sec.
# unable to find the google news vec for word:  and
# proced sent: 7 in 0.00367903709412 sec.
# unable to find the google news vec for word:  and
# proced sent: 8 in 0.00351285934448 sec.
# unable to find the google news vec for word:  and
# proced sent: 9 in 0.00337505340576 sec.
# unable to find the google news vec for word:  and
# proced sent: 10 in 0.00325417518616 sec.
# unable to find the google news vec for word:  and
# proced sent: 11 in 0.00313377380371 sec.
# unable to find the google news vec for word:  and
# proced sent: 12 in 0.00303101539612 sec.
# proced sent: 13 in 0.00100088119507 sec.
# proced sent: 14 in 0.0063419342041 sec.
# proced sent: 15 in 0.000471115112305 sec.
# unable to find the google news vec for word:  and
# proced sent: 16 in 0.00266981124878 sec.
# unable to find the google news vec for word:  tikkamasala
# unable to find the google news vec for word:  and
# proced sent: 17 in 0.00194597244263 sec.
# unable to find the google news vec for word:  tikkamasala
# unable to find the google news vec for word:  and
# proced sent: 18 in 0.00197196006775 sec.
# unable to find the google news vec for word:  tikkamasala
# unable to find the google news vec for word:  and
# proced sent: 19 in 0.00203490257263 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# proced sent: 20 in 0.00691914558411 sec.
# unable to find the google news vec for word:  a
# proced sent: 21 in 0.00343203544617 sec.
# proced sent: 22 in 0.000808000564575 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# proced sent: 23 in 0.00143790245056 sec.
# proced sent: 24 in 0.000663042068481 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  of
# proced sent: 25 in 0.00718688964844 sec.
# unable to find the google news vec for word:  and
# proced sent: 26 in 0.00334000587463 sec.
# unable to find the google news vec for word:  and
# proced sent: 27 in 0.00331497192383 sec.
# unable to find the google news vec for word:  and
# proced sent: 28 in 0.0468552112579 sec.
# unable to find the google news vec for word:  and
# proced sent: 29 in 0.043025970459 sec.
# unable to find the google news vec for word:  and
# proced sent: 30 in 0.0504679679871 sec.
# unable to find the google news vec for word:  and
# proced sent: 31 in 0.0446908473969 sec.
# unable to find the google news vec for word:  and
# proced sent: 32 in 0.0459890365601 sec.
# unable to find the google news vec for word:  and
# proced sent: 33 in 0.0429351329803 sec.
# unable to find the google news vec for word:  and
# proced sent: 34 in 0.0428268909454 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  of
# proced sent: 35 in 0.0123410224915 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  of
# proced sent: 36 in 0.0134210586548 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  of
# proced sent: 37 in 0.0125181674957 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  didnt
# unable to find the google news vec for word:  a
# proced sent: 38 in 0.0184350013733 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  didnt
# unable to find the google news vec for word:  a
# proced sent: 39 in 0.0186269283295 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  a
# proced sent: 40 in 0.00594282150269 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  doesnt
# unable to find the google news vec for word:  a
# proced sent: 41 in 0.00824904441833 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  doesnt
# unable to find the google news vec for word:  a
# proced sent: 42 in 0.00811290740967 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  doesnt
# unable to find the google news vec for word:  a
# proced sent: 43 in 0.00768303871155 sec.
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  of
# proced sent: 44 in 0.0118501186371 sec.
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  of
# proced sent: 45 in 0.0117421150208 sec.
# proced sent: 46 in 0.0043089389801 sec.
# proced sent: 47 in 0.00427412986755 sec.
# proced sent: 48 in 0.0042610168457 sec.
# proced sent: 49 in 0.00425601005554 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 50 in 0.0110940933228 sec.
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  and
# proced sent: 51 in 0.00269508361816 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  gaskin
# proced sent: 52 in 0.0119080543518 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  gaskin
# proced sent: 53 in 0.0118939876556 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  gaskin
# proced sent: 54 in 0.0118930339813 sec.
# unable to find the google news vec for word:  to
# proced sent: 55 in 0.0125279426575 sec.
# unable to find the google news vec for word:  to
# proced sent: 56 in 0.0124499797821 sec.
# unable to find the google news vec for word:  to
# proced sent: 57 in 0.0151808261871 sec.
# unable to find the google news vec for word:  to
# proced sent: 58 in 0.0126769542694 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  to
# proced sent: 59 in 0.0313408374786 sec.
# unable to find the google news vec for word:  and
# proced sent: 60 in 0.0055091381073 sec.
# unable to find the google news vec for word:  and
# proced sent: 61 in 0.00578308105469 sec.
# unable to find the google news vec for word:  and
# proced sent: 62 in 0.00595283508301 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  of
# proced sent: 63 in 0.00261092185974 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  of
# proced sent: 64 in 0.00250101089478 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  of
# proced sent: 65 in 0.00228714942932 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  to
# proced sent: 66 in 0.0065860748291 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  to
# proced sent: 67 in 0.0064971446991 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  to
# proced sent: 68 in 0.00647902488708 sec.
# unable to find the google news vec for word:  930
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 69 in 0.00996208190918 sec.
# unable to find the google news vec for word:  wasnt
# proced sent: 70 in 0.0129930973053 sec.
# unable to find the google news vec for word:  wasnt
# proced sent: 71 in 0.0129160881042 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 72 in 0.00184011459351 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 73 in 0.00180602073669 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  massamman
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# proced sent: 74 in 0.00961899757385 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  massamman
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# proced sent: 75 in 0.00960302352905 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  massamman
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# proced sent: 76 in 0.00970005989075 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  massamman
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# proced sent: 77 in 0.00963401794434 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  massamman
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# proced sent: 78 in 0.00962996482849 sec.
# proced sent: 79 in 0.000477075576782 sec.
# unable to find the google news vec for word:  a
# proced sent: 80 in 0.00457906723022 sec.
# unable to find the google news vec for word:  a
# proced sent: 81 in 0.00455904006958 sec.
# unable to find the google news vec for word:  a
# proced sent: 82 in 0.00455188751221 sec.
# unable to find the google news vec for word:  25
# proced sent: 83 in 0.00264406204224 sec.
# unable to find the google news vec for word:  25
# proced sent: 84 in 0.00260591506958 sec.
# unable to find the google news vec for word:  25
# proced sent: 85 in 0.00265908241272 sec.
# unable to find the google news vec for word:  and
# proced sent: 86 in 0.00301194190979 sec.
# unable to find the google news vec for word:  and
# proced sent: 87 in 0.00203514099121 sec.
# unable to find the google news vec for word:  and
# proced sent: 88 in 0.00434112548828 sec.
# unable to find the google news vec for word:  and
# proced sent: 89 in 0.00426816940308 sec.
# unable to find the google news vec for word:  and
# proced sent: 90 in 0.00427913665771 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  virgnin
# proced sent: 91 in 0.0142579078674 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  virgnin
# proced sent: 92 in 0.0143051147461 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  virgnin
# proced sent: 93 in 0.0141580104828 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  virgnin
# proced sent: 94 in 0.0141320228577 sec.
# unable to find the google news vec for word:  and
# proced sent: 95 in 0.00696802139282 sec.
# proced sent: 96 in 0.000673055648804 sec.
# proced sent: 97 in 0.00138187408447 sec.
# proced sent: 98 in 0.00133204460144 sec.
# unable to find the google news vec for word:  lambchops
# proced sent: 99 in 0.00139021873474 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  of
# proced sent: 100 in 0.0179810523987 sec.
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  to
# proced sent: 101 in 0.0028920173645 sec.
# unable to find the google news vec for word:  and
# proced sent: 102 in 0.0423638820648 sec.
# unable to find the google news vec for word:  and
# proced sent: 103 in 0.00231194496155 sec.
# unable to find the google news vec for word:  and
# proced sent: 104 in 0.00228905677795 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 105 in 0.00679087638855 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 106 in 0.00681209564209 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 107 in 0.00680804252625 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 108 in 0.00685691833496 sec.
# proced sent: 109 in 0.000830888748169 sec.
# unable to find the google news vec for word:  and
# proced sent: 110 in 0.00383496284485 sec.
# unable to find the google news vec for word:  and
# proced sent: 111 in 0.00384497642517 sec.
# proced sent: 112 in 0.00203204154968 sec.
# proced sent: 113 in 0.00202989578247 sec.
# proced sent: 114 in 0.00204682350159 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 115 in 0.0156319141388 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 116 in 0.0248141288757 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  uncourteous
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# proced sent: 117 in 0.168380022049 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 118 in 0.0137438774109 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 119 in 0.0207860469818 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 120 in 0.0172901153564 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 121 in 0.00979685783386 sec.
# unable to find the google news vec for word:  and
# proced sent: 122 in 0.0013530254364 sec.
# unable to find the google news vec for word:  and
# proced sent: 123 in 0.00128889083862 sec.
# unable to find the google news vec for word:  and
# proced sent: 124 in 0.00494909286499 sec.
# unable to find the google news vec for word:  and
# proced sent: 125 in 0.00476980209351 sec.
# unable to find the google news vec for word:  and
# proced sent: 126 in 0.00440812110901 sec.
# unable to find the google news vec for word:  and
# proced sent: 127 in 0.0048201084137 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  a
# proced sent: 128 in 0.00223898887634 sec.
# unable to find the google news vec for word:  prixe
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  to
# proced sent: 129 in 0.0316150188446 sec.
# unable to find the google news vec for word:  prixe
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  to
# proced sent: 130 in 0.0315449237823 sec.
# unable to find the google news vec for word:  prixe
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  to
# proced sent: 131 in 0.0312628746033 sec.
# unable to find the google news vec for word:  prixe
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  to
# proced sent: 132 in 0.0313658714294 sec.
# unable to find the google news vec for word:  prixe
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  to
# proced sent: 133 in 0.0387499332428 sec.
# unable to find the google news vec for word:  prixe
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  to
# proced sent: 134 in 0.050449848175 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  a
# proced sent: 135 in 0.0335900783539 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  a
# proced sent: 136 in 0.029088973999 sec.
# unable to find the google news vec for word:  brushetta
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# proced sent: 137 in 0.00429201126099 sec.
# unable to find the google news vec for word:  brushetta
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# proced sent: 138 in 0.00357389450073 sec.
# proced sent: 139 in 0.00484895706177 sec.
# proced sent: 140 in 0.00461912155151 sec.
# unable to find the google news vec for word:  ballatos
# proced sent: 141 in 0.00123500823975 sec.
# proced sent: 142 in 0.000894784927368 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 143 in 0.0102138519287 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 144 in 0.0105459690094 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 145 in 0.00984907150269 sec.
# unable to find the google news vec for word:  and
# proced sent: 146 in 0.00137805938721 sec.
# unable to find the google news vec for word:  and
# proced sent: 147 in 0.00162792205811 sec.
# unable to find the google news vec for word:  and
# proced sent: 148 in 0.00174403190613 sec.
# proced sent: 149 in 0.00109505653381 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# proced sent: 150 in 0.00241613388062 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 151 in 0.00389409065247 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 152 in 0.00379920005798 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 153 in 0.00449299812317 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  volare
# unable to find the google news vec for word:  and
# proced sent: 154 in 0.00212407112122 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  volare
# unable to find the google news vec for word:  and
# proced sent: 155 in 0.00200796127319 sec.
# unable to find the google news vec for word:  and
# proced sent: 156 in 0.00170111656189 sec.
# unable to find the google news vec for word:  and
# proced sent: 157 in 0.00166606903076 sec.
# unable to find the google news vec for word:  and
# proced sent: 158 in 0.001620054245 sec.
# proced sent: 159 in 0.00393509864807 sec.
# proced sent: 160 in 0.00552487373352 sec.
# proced sent: 161 in 0.00726819038391 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  20
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  45
# proced sent: 162 in 0.289956092834 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  20
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  45
# proced sent: 163 in 0.253689050674 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  20
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  45
# proced sent: 164 in 0.244272947311 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  20
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  45
# proced sent: 165 in 0.27067899704 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  20
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  45
# proced sent: 166 in 0.253522157669 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  20
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  45
# proced sent: 167 in 0.248834133148 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  to
# proced sent: 168 in 0.0115299224854 sec.
# proced sent: 169 in 0.00828099250793 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 170 in 0.0152411460876 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 171 in 0.000369071960449 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 172 in 0.000349998474121 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 173 in 0.00034499168396 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 174 in 0.000334978103638 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  a
# proced sent: 175 in 0.0080349445343 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 176 in 0.00528192520142 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 177 in 0.00524997711182 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 178 in 0.00511002540588 sec.
# unable to find the google news vec for word:  and
# proced sent: 179 in 0.00175809860229 sec.
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  of
# proced sent: 180 in 0.00270199775696 sec.
# proced sent: 181 in 0.00126504898071 sec.
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  of
# proced sent: 182 in 0.00379109382629 sec.
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  of
# proced sent: 183 in 0.00371599197388 sec.
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  and
# proced sent: 184 in 0.00200796127319 sec.
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  and
# proced sent: 185 in 0.0020740032196 sec.
# proced sent: 186 in 0.000676155090332 sec.
# unable to find the google news vec for word:  to
# proced sent: 187 in 0.00231504440308 sec.
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 188 in 0.00881099700928 sec.
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  and
# proced sent: 189 in 0.00880718231201 sec.
# unable to find the google news vec for word:  and
# proced sent: 190 in 0.00196504592896 sec.
# unable to find the google news vec for word:  and
# proced sent: 191 in 0.00194406509399 sec.
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# proced sent: 192 in 0.024735212326 sec.
# unable to find the google news vec for word:  awfulthe
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  to
# proced sent: 193 in 0.0297012329102 sec.
# unable to find the google news vec for word:  awfulthe
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  to
# proced sent: 194 in 0.0295550823212 sec.
# proced sent: 195 in 0.000584840774536 sec.
# unable to find the google news vec for word:  and
# proced sent: 196 in 0.00100803375244 sec.
# unable to find the google news vec for word:  of
# unable to find the google news vec for word:  a
# proced sent: 197 in 0.00124597549438 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  to
# proced sent: 198 in 0.0164310932159 sec.
# unable to find the google news vec for word:  to
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  and
# unable to find the google news vec for word:  a
# unable to find the google news vec for word:  of
# proced sent: 199 in 0.00550603866577 sec.

# %%
UnScaledX = np.array (UnScaledX)
ScaledX = np.array (ScaledX)

# %%
print UnScaledX.shape
print ScaledX.shape
# Out:
# (200, 18300)
# (200, 18300)

# %%
UnScaledX = UnScaledX.reshape(200,18300)
ScaledX = ScaledX.reshape(200,18300)

# %%
np.savetxt (fname='UnscaledX.txt',X = UnScaledX)
np.savetxt (fname='ScaledX.txt',X = ScaledX)

# %%
print Y.shape
print type(Y)
with open ('Y.txt','w') as FH:
    for y in Y:
        print>>FH, y
# Out:
# (200,)
# <type 'numpy.ndarray'>
